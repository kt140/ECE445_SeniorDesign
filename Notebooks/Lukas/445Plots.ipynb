# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import time
mpl.style.use('ggplot')


x = np.linspace(0,20,20)
y = x* 0.5

v = np.array(
    [0,
     0.5,
     1.005,
     1.507,
     2.008,
     3.75,
     5.54, 
     6.53,
     7.07,
     7.470, 
     7.710, 
     7.672,
     7.585,
     7.553,
     7.535,
     7.526,
     7.521,
     7.52,
     7.521,
     7.525
    ]
)
plt.figure()
plt.plot(x,y)
plt.plot(x,v)
plt.title('Buck Converter Non-Linearity for D=50%')
plt.xlabel('Input Voltage')
plt.ylabel('Output Voltage')
plt.legend(['Ideal Result', 'Output of the Buck'])

plt.show()
